# %%
import pandas as pd

# %% [markdown]
# Subset data with Pandas

# %%
df = pd.read_csv(
    "/content/sample_data/california_housing_train.csv",
    usecols=["population", "median_income"]
    )

df.head()
# Out:
#    population  median_income
# 0      1015.0         1.4936
# 1      1129.0         1.8200
# 2       333.0         1.6509
# 3       515.0         3.1917
# 4       624.0         1.9250

# %% [markdown]
# Filter data with Pandas

# %%
df[df['median_income'] > 3].head()
# Out:
#     population  median_income
# 3        515.0         3.1917
# 5        671.0         3.3438
# 13      1346.0         3.2120
# 23       137.0         3.2097
# 25       327.0         3.6528

# %%
df[(df['median_income'] > 3) & (df['population'] > 1000)].head()
# Out:
#     population  median_income
# 13      1346.0         3.2120
# 26      1130.0         3.5735
# 67      1188.0         3.0091
# 70      1447.0         3.2593
# 76      1164.0         3.8177

# %% [markdown]
# Find top 5 largest and smallest median incomes.

# %%
df.nlargest(5, "median_income")
# Out:
#       population  median_income
# 1625      1011.0        15.0001
# 3338       735.0        15.0001
# 4461       268.0        15.0001
# 4626       964.0        15.0001
# 5048       956.0        15.0001

# %%
df.nsmallest(5, "median_income")
# Out:
#       population  median_income
# 340        108.0         0.4999
# 2888        44.0         0.4999
# 4502        15.0         0.4999
# 4689       142.0         0.4999
# 6631        74.0         0.4999

# %% [markdown]
# # Recode data

# %%
data = pd.Series(data=["female", "male", "male", "female", "female"])
random_df = pd.DataFrame(data=data, columns=["sex"])

# %%
def recode(sex):
    if sex == "male":
        return 1
    else:
        return 0

random_df['sex'] = random_df['sex'].apply(recode)
random_df
# Out:
#    sex
# 0    0
# 1    1
# 2    1
# 3    0
# 4    0

# %%
random_df['sex'] = random_df['sex'].apply(lambda x: 1 if x == "male" else 0)

# %%
import numpy as np

random_df['sex'] = np.where(random_df['sex'] == "male", 1, 0)

# %% [markdown]
# # Transform data with Python

# %%
log_income = np.log(df['median_income'])
log_income.head()
# Out:
# 0    0.401189
# 1    0.598837
# 2    0.501321
# 3    1.160554
# 4    0.654926
# Name: median_income, dtype: float64

# %% [markdown]
# # (Un)common data wrangling operations

# %%
# Grouping data
random.groupby("day_of_wek")

# %%
# Aggregating data
df['population'].agg(np.median)
# Out:
# 1167.0

# %%
# Querying data
df.query('population <= 1000 & median_income >= 3').head()
# Out:
#     population  median_income
# 3        515.0         3.1917
# 5        671.0         3.3438
# 23       137.0         3.2097
# 25       327.0         3.6528
# 32       481.0         6.2558

# %%
numbers = ['1', '2' , '3', '4']

print(type(numbers[0]))

# Change type
numbers = list(map(int, numbers))

print(type(numbers[0]))
# Out:
# <class 'str'>
# <class 'int'>

# %%
df['population'].astype(str).head()
# Out:
# 0    1015.0
# 1    1129.0
# 2     333.0
# 3     515.0
# 4     624.0
# Name: population, dtype: object

# %%
 pd.to_numeric(df.population).head()
# Out:
# 0    1015.0
# 1    1129.0
# 2     333.0
# 3     515.0
# 4     624.0
# Name: population, dtype: float64

# %%
# Reordirng
df['population'].sort_values(ascending=False).head()
# Out:
# 2274     35682.0
# 12772    28566.0
# 2871     16122.0
# 2969     15507.0
# 3296     15037.0
# Name: population, dtype: float64

# %%
# Reorder columns
column_names_reordered = ["3", "2", "1"]

df = df.reindex(columns=column_names_reordered)

# %%
# Join data

data_1 = df[:3]
data_2 = df[3:6]

joined_data = pd.concat([data_1, data_2], axis=0)
joined_data
# Out:
#    population  median_income
# 0      1015.0         1.4936
# 1      1129.0         1.8200
# 2       333.0         1.6509
# 3       515.0         3.1917
# 4       624.0         1.9250
# 5       671.0         3.3438

# %%
# Rename data
df.rename(columns = {'old_col1':'new_col1', 'old_col2':'new_col2'}, inplace = True)

# %% [markdown]
# # Pivot data with Pandas

# %%
df = pd.read_csv(
    "/content/sample_data/california_housing_train.csv"
    )

df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
table = pd.pivot_table(data=df,index=['households'])
table.tail()
# Out:
#             housing_median_age  latitude  longitude  median_house_value  \
# households
# 4616.0                    10.0     33.98    -117.34            103400.0
# 4769.0                    14.0     33.35    -117.42            134400.0
# 5050.0                     8.0     34.03    -117.78            253900.0
# 5189.0                     4.0     33.89    -117.74            366300.0
# 6082.0                    11.0     36.64    -121.79            118800.0
#
#             median_income  population  total_bedrooms  total_rooms
# households
# 4616.0             1.7579      9851.0          4952.0      17286.0
# 4769.0             2.5729     35682.0          4819.0      25135.0
# 5050.0             6.0191     15507.0          5290.0      32054.0
# 5189.0             7.4947     16122.0          5471.0      37937.0
# 6082.0             2.3087     28566.0          6445.0      32627.0

# %% [markdown]
# # Wrangling Text Data

# %%
# Splitting text data
sentence = "Hello Algotrading101 readers! I hope that you are having a nice day."

words = sentence.split(" ")
print(words)
# Out:
# ['Hello', 'Algotrading101', 'readers!', 'I', 'hope', 'that', 'you', 'are', 'having', 'a', 'nice', 'day.']

# %%
# (De)capitalize text data
word = 'pumpkin'

print(word.upper())
print(word.lower())
print(word.capitalize())
# Out:
# PUMPKIN
# pumpkin
# Pumpkin

# %%
# Join text data
print(' '.join(words))
# Out:
# Hello Algotrading101 readers! I hope that you are having a nice day.
